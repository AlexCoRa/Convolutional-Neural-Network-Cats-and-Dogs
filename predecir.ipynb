# %%
import numpy as np
import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
tf.compat.v1.keras.backend.set_session(tf.compat.v1.Session(config=config))
from keras.preprocessing.image import load_img, img_to_array
from keras.models import load_model
import matplotlib.pyplot as plt

# %%
longitud, altura=150,150
modelo='./modelo/modelo.h5'
pesos='./modelo/pesos.h5'

# %% [markdown]
# ### cargar el modelo que hicimos en entrenar

# %%
cnn=load_model(modelo)
cnn.load_weights(pesos)

# %%
def predict(file):
  x = load_img(file, target_size=(longitud, altura))
  x = img_to_array(x)
  x=x/255
  plt.imshow(x)
  plt.show()
  x = np.expand_dims(x, axis=0)
  array = cnn.predict(x)
  result = array[0]
  answer = np.argmax(result)

  if answer == 0:
    print("Gato")
  elif answer == 1:
    print("Perro") 
  return answer

# %%
predict('./Imagenes_prueba/cat.3.jpg')
predict('./Imagenes_prueba/cat.49.jpg')
predict('./Imagenes_prueba/cat.54.jpg')
predict('./Imagenes_prueba/cat1.jpg')
predict('./Imagenes_prueba/cat2.jpg')
predict('./Imagenes_prueba/cat3.jpg')
predict('./Imagenes_prueba/cat4.jpg')
predict('./Imagenes_prueba/cat5.jpg')
predict('./Imagenes_prueba/cat6.jpg')
predict('./Imagenes_prueba/cat7.jpg')
predict('./Imagenes_prueba/cat8.jpg')
predict('./Imagenes_prueba/cat9.jpg')
predict('./Imagenes_prueba/gato3.jpeg')
predict('./Imagenes_prueba/dog.20.jpg')
predict('./Imagenes_prueba/dog.30.jpg')
predict('./Imagenes_prueba/dog.31.jpg')
predict('./Imagenes_prueba/dog1.jpg')
predict('./Imagenes_prueba/dog2.jpg')
predict('./Imagenes_prueba/dog3.jpg')
predict('./Imagenes_prueba/dog4.jpg')
predict('./Imagenes_prueba/dog5.jpg')
predict('./Imagenes_prueba/dog6.jpg')
# Out:
# Gato
# Gato
# Perro
# Gato
# Gato
# Perro
# Gato
# Gato
# Gato
# Perro
# Gato
# Perro
# Gato
# Perro
# Perro
# Perro
# Perro
# Perro
# Perro
# Perro
# Perro
# Perro
# 1
